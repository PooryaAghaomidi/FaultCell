# %%
import numpy as np
import scipy.io
mat = scipy.io.loadmat('../Dataset/Batch-1/dataset_amb.mat')

# %%
mat['irr'].shape
# Out:
# (1, 1373798)

# %%
list(mat['f_nv'].flatten()).count(1)
# Out:
# 5999

# %%
list(mat['f_nv'].flatten()).count(0)
# Out:
# 1162931

# %%
mat = scipy.io.loadmat('../Dataset/Batch-1/dataset_elec.mat')

# %%
mat['idc1'].shape
# Out:
# (1, 1373798)

# %%
import pandas as pd
data_dict = pd.read_csv('../Dataset/Batch-3/CSV_Files/CSV_Files/F0L.csv')
data_dict
# Out:
#              Time       Ipv         Vpv         Vdc        ia        ib  \
# 0        0.000028  1.572327  101.348877  144.140625 -0.135133  0.490112
# 1        0.000128  1.503265  101.458740  143.554688 -0.108277  0.510254
# 2        0.000228  1.492859  101.574707  143.554688 -0.168702  0.496826
# 3        0.000328  1.558136  101.312256  143.261719 -0.135133  0.510254
# 4        0.000428  1.631927  101.141357  143.847656 -0.202271  0.503540
# ...           ...       ...         ...         ...       ...       ...
# 143710  14.369575  1.376495  101.824951  141.796875  0.052855 -0.463257
# 143711  14.369675  1.433258  100.848389  142.382812  0.072997 -0.463257
# 143712  14.369775  1.481506  100.885010  142.675781  0.079711 -0.483398
# 143713  14.369875  1.484344  101.397705  142.675781  0.106566 -0.476685
# 143714  14.369975  1.381226  102.056885  142.089844  0.119994 -0.476685
#
#               ic         va          vb          vc      Iabc         If  \
# ...

# %%
data_dict = pd.read_csv('../Dataset/Batch-3/CSV_Files/CSV_Files/F1M.csv')
data_dict
# Out:
#              Time       Ipv        Vpv         Vdc        ia        ib  \
# 0        0.000038  2.260101  88.500977  147.363281  0.563109 -0.020142
# 1        0.000138  2.465393  88.000488  145.605469  0.569823  0.006714
# 2        0.000238  2.621490  86.914062  147.949219  0.549682  0.020142
# 3        0.000338  2.509857  88.079834  147.949219  0.549682  0.046997
# 4        0.000438  2.291321  88.348389  147.949219  0.542968  0.073853
# ...           ...       ...        ...         ...       ...       ...
# 139009  13.899535  3.031128   2.105713    1.171875  0.019286 -0.013428
# 139010  13.899635  3.038696   2.209473    1.464844  0.019286 -0.013428
# 139011  13.899735  3.043427   2.301025    1.171875  0.019286 -0.006714
# 139012  13.899835  3.033020   2.386475    1.171875  0.019286 -0.006714
# 139013  13.899935  3.020721   2.478027    1.171875  0.019286 -0.006714
#
#               ic          va         vb          vc      Iabc         If  \
# ...

# %%
data_dict.iloc[0:10]
# Out:
#        Time       Ipv        Vpv         Vdc        ia        ib        ic  \
# 0  0.000038  2.260101  88.500977  147.363281  0.563109 -0.020142 -0.563115
# 1  0.000138  2.465393  88.000488  145.605469  0.569823  0.006714 -0.576543
# 2  0.000238  2.621490  86.914062  147.949219  0.549682  0.020142 -0.576543
# 3  0.000338  2.509857  88.079834  147.949219  0.549682  0.046997 -0.576543
# 4  0.000438  2.291321  88.348389  147.949219  0.542968  0.073853 -0.583257
# 5  0.000538  2.264832  88.305664  147.949219  0.522826  0.087280 -0.596685
# 6  0.000638  2.462555  88.055420  148.242188  0.516112  0.120850 -0.596685
# 7  0.000738  2.558105  87.689209  148.242188  0.502685  0.127563 -0.610112
# 8  0.000838  2.464447  88.220215  147.656250  0.495971  0.154419 -0.610112
# 9  0.000938  2.261993  88.439941  147.949219  0.482543  0.167847 -0.616826
#
#            va         vb          vc  Iabc    If  Vabc    Vf
# 0 -142.001343  18.901367  124.799652   1.0  50.0   1.0  50.0
# ...

# %%
data_dict = data_dict.drop('Time', axis=1)

# %%
np.array(data_dict.iloc[0:10])
# Out:
# array([[ 2.26010132e+00,  8.85009766e+01,  1.47363281e+02,
#          5.63109375e-01, -2.01416016e-02, -5.63115234e-01,
#         -1.42001343e+02,  1.89013672e+01,  1.24799652e+02,
#          1.00000000e+00,  5.00000000e+01,  1.00000000e+00,
#          5.00000000e+01],
#        [ 2.46539307e+00,  8.80004883e+01,  1.45605469e+02,
#          5.69823242e-01,  6.71386719e-03, -5.76542969e-01,
#         -1.39855652e+02,  1.53694153e+01,  1.28347677e+02,
#          1.00000000e+00,  5.00000000e+01,  1.00000000e+00,
#          5.00000000e+01],
#        [ 2.62149048e+00,  8.69140625e+01,  1.47949219e+02,
#          5.49681641e-01,  2.01416016e-02, -5.76542969e-01,
#         -1.35624542e+02,  8.92028809e+00,  1.29484812e+02,
#          1.00000000e+00,  5.00000000e+01,  1.00000000e+00,
#          5.00000000e+01],
#        [ 2.50985718e+00,  8.80798340e+01,  1.47949219e+02,
#          5.49681641e-01,  4.69970703e-02, -5.76542969e-01,
#         -1.36637115e+02,  6.00311279e+00,  1.32896220e+02,
# ...

# %%
import numpy as np
